# %% [markdown]
# # Download Daymet

# %% [markdown]
# Daymet provides gridded meteorological data for North American at 1km spatial resolution with daily timestep from 1980 ~ present. [website](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1328) and [user guide](https://daac.ornl.gov/DAYMET/guides/Daymet_V3_CFMosaics.html)
#
# Available variables:
#
# | Variable | Description (units) |
# | ---- | ---- |
# | tmax | Daily maximum 2-meter air temperature (°C) |
# | tmin | Daily minimum 2-meter air temperature (°C) |
# | prcp | Daily total precipitation (mm/day) |
# | srad | Incident shortwave radiation flux density (W/m2) |
# | vp   | Water vapor pressure (Pa) |
# | swe  | Snow water equivalent (kg/m2) |
# | dayl | Duration of the daylight period (seconds) |
#
# Notes:
#  - The Daymet calendar is based on a standard calendar year. <span style="color:blue;"> All Daymet years, including leap years, have 365 days. Keep this in mind during post-processing of model results!</span>  For leap years, the Daymet database includes leap day (February 29) and values for December 31 are discarded from leap years to maintain a 365-day year.
#
#  - DayMet's incident shortwave radiation is the "daylit" radiation.  To get the daily average radiation, one must multiply by daylit fraction, given by dayl / 86400.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
import logging,yaml
import numpy as np
import rasterio
import fiona
import os
import datetime 

import watershed_workflow
import watershed_workflow.ui
import watershed_workflow.sources.manager_daymet
import watershed_workflow.daymet
import watershed_workflow.io

watershed_workflow.ui.setup_logging(1,None)

# %%
watershed_shapefile = '../../data/examples/CoalCreek/sources/shapefile/CoalCreek.shp'
# config_fname = '../../data/examples/CoalCreek/processed/config.yaml'

# %%
# # Load the dictionary from the file
# with open(config_fname, 'r') as file:
#     config = yaml.load(file, Loader=yaml.FullLoader)

# %%
# dates are in YYYY-MM-DD
# start and end of simulation -- one year of simulation that is in both the MODIS and DayMet dataset ranges
# start_date = config['start_date']
# end_date = config['end_date']
# origin_date = config['origin_date']


# start_date = "2014-10-1"
# end_date = "2022-10-1"


start_date = "2014-10-1"
end_date = "2021-10-1"
# origin_date = config['origin_date']
origin_date = "1980-1-1"

# %% [markdown]
# ## import watershed

# %%
crs, watershed = watershed_workflow.get_split_form_shapes(watershed_shapefile)
logging.info(f'crs: {crs}')

bounds = watershed.exterior().bounds
print(bounds)
print(bounds[2] - bounds[0], bounds[3] - bounds[1])
# Out:
# 2024-09-21 22:20:34,906 - root - INFO:
# 2024-09-21 22:20:34,909 - root - INFO: Loading shapes
# 2024-09-21 22:20:34,910 - root - INFO: ------------------------------
# 2024-09-21 22:20:34,911 - root - INFO: Loading file: '../../data/examples/CoalCreek/sources/shapefile/CoalCreek.shp'
# 2024-09-21 22:20:35,007 - root - INFO: ... found 1 shapes
# 2024-09-21 22:20:35,007 - root - INFO: Converting to shapely
# 2024-09-21 22:20:35,014 - root - INFO: crs: epsg:26913
# (317251.2640131897, 4299711.408984916, 328473.7039815487, 4307062.45088187)
# 11222.439968359016 7351.041896954179

# %%
watershed.exterior()

# %% [markdown]
# ## Download

# %% [markdown]
# returned raw data has `dim(nband, ncol, nrow)`

# %%
# setting vars = None to download all available variables
source = watershed_workflow.sources.manager_daymet.FileManagerDaymet()
data = source.get_data(bounds, crs, start = start_date, end = end_date, buffer=0.02)
# Out:
# 2024-09-21 22:20:35,062 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,082 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,083 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,102 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,104 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,116 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,117 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,136 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,137 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,155 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,156 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,172 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,173 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,191 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,192 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,210 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,211 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,228 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,229 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,246 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,247 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,261 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,262 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,281 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,282 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,298 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,299 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,317 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,317 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,334 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,334 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,346 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,347 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,362 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,363 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,382 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,382 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,396 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,397 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,413 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,414 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,431 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,432 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,443 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,444 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,456 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,457 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,468 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,469 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,481 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,482 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,493 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,493 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,504 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,505 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,520 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,521 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,534 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,535 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,549 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,550 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,564 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,565 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,580 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,580 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,597 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,597 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,613 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,614 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,630 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,631 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,648 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,649 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,664 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,665 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,678 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,679 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,692 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,693 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,706 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,707 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,725 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,726 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,736 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,737 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,747 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,747 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,758 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,759 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,770 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,771 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,787 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,788 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,804 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-09-21 22:20:35,805 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-09-21 22:20:35,819 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2021_38.9157x-107.1272_38.8072x-106.9560.nc

# %% [markdown]
# ## Reproject Daymet CRS
#
# Reproject daymet CRS to the same as the watershed. This is necessary if watershed meshes are using watershed CRS.

# %%
data_new = watershed_workflow.warp.state(data, dst_crs=crs)

# %% [markdown]
# ## plot Daymet

# %%
ivar = 'tmax'
islice = 100
daymet_crs = watershed_workflow.crs.daymet_crs()

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(daymet_crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_ext_daymet = watershed_workflow.warp.shply(watershed.exterior(),
                                                     crs, daymet_crs)
watershed_workflow.plot.raster(data[ivar].profile, data[ivar].data[islice,:,:], ax1)
watershed_workflow.plot.shply(watershed_ext_daymet, daymet_crs, ax=ax1, color='r')

watershed_workflow.plot.raster(data_new[ivar].profile, data_new[ivar].data[islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Reprojected Daymet")
# Out:
# /opt/conda/envs/watershed_workflow/lib/python3.10/site-packages/pyproj/crs/crs.py:1282: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 2024-09-21 22:20:40,165 - root - INFO: BOUNDS: (-591250.0, -367000.0, -576250.0, -355000.0)
# 2024-09-21 22:20:40,177 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364619, 4310206.812630757)
# Text(0.5, 1.0, 'Reprojected Daymet')

# %% [markdown]
# # save daymet

# %% [markdown]
# ## Write data to HDF5

# %% [markdown]
# This will write daymet in a format that ATS can read. E.g., this will calculate mean air temperature, convert units, partition precipitation into rain and snow based on mean temp, and so on.
#
# - dout has dims of `(ntime, nrow, ncol)` or `(ntime, ny, nx)`

# %%
assert(len(data_new.collections) == 1)
met_data = data_new.collections[0]

# %%
# met_data_ats = watershed_workflow.daymet.daymet_to_daily_averages(met_data)


# config['daymet_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_raw.h5')
# attrs = watershed_workflow.daymet.getAttributes(bounds, start_date, end_date)
# attrs['name']="Daymet forcing reformatted for ats modeling"

# watershed_workflow.io.write_dataset_to_hdf5(
#     filename = config['daymet_filename'],
#     dataset= met_data_ats.collections[0],
#     attributes= attrs,
#     time0 = origin_date
# )


met_data_ats = watershed_workflow.daymet.daymet_to_daily_averages(met_data)
#daymet_filename = os.path.join('..', '..', 'data', 'examples', 'CoalCreek', 'processed', 'watershed_daymet_raw.h5')

daymet_filename = os.path.join('..', '..', 'data', 'examples', 'CoalCreek', 'processed', 'coalcreek_daymet_raw.h5')

# Get attributes for the dataset
attrs = watershed_workflow.daymet.getAttributes(bounds, start_date, end_date)
attrs['name']="Daymet forcing reformatted for ats modeling"

# Write the processed Daymet data to an HDF5 file
watershed_workflow.io.write_dataset_to_hdf5(
    filename=daymet_filename,
    dataset= met_data_ats.collections[0],
    attributes= attrs,
    time0 = origin_date
)
# Out:
# 2024-09-21 22:20:40,306 - root - INFO: Converting to ATS met input
# 2024-09-21 22:20:40,355 - root - INFO: Writing HDF5 file: ../../data/examples/CoalCreek/processed/coalcreek_daymet_raw.h5

# %% [markdown]
# ## Write typical Daymet
#
# This will average days, smooths the forcing and generate a "typical year" data, then looped 10 years. The dataset will be used during cyclic spinup.

# %%
# config['daymet_typical_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')

# met_data_typical = watershed_workflow.datasets.State()
# ntypical_years = 10
# # here we make up some new times. 
# # It does not really matter what timeframe you choose as long as the nunmber of days are consistent.
# new_times = np.array([datetime.date(1980,10,1) + datetime.timedelta(days=i) for i in range(365*ntypical_years)])

# for (ds_key, ds_val) in met_data_ats.items():
#     # average and smooth forcing data. Hint: make filter=False if no smoothing is needed.
#     smooth_dat = watershed_workflow.utils.compute_average_year(ds_val.data, output_nyears=ntypical_years, filter=True)
#     met_data_typical[ds_key] = watershed_workflow.datasets.Dataset(ds_val.profile, new_times, smooth_dat)

# attrs = watershed_workflow.daymet.getAttributes(bounds, new_times[0], new_times[-1])
# attrs['name']=f"{ntypical_years}-yrs typical Daymet forcing generated using data from {start_date} to {end_date}"

# watershed_workflow.io.write_dataset_to_hdf5(config['daymet_typical_filename'], met_data_typical.collections[0], 
#                                             attributes=attrs, time0=origin_date)

#daymet_typical_filename = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')
daymet_typical_filename = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','coalcreek_daymet_typical.h5')
# config['daymet_typical_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')

met_data_typical = watershed_workflow.datasets.State()
ntypical_years = 10
# here we make up some new times. 
# It does not really matter what timeframe you choose as long as the nunmber of days are consistent.
new_times = np.array([datetime.date(1980,10,1) + datetime.timedelta(days=i) for i in range(365*ntypical_years)])

for (ds_key, ds_val) in met_data_ats.items():
    # average and smooth forcing data. Hint: make filter=False if no smoothing is needed.
    smooth_dat = watershed_workflow.utils.compute_average_year(ds_val.data, output_nyears=ntypical_years, filter=True)
    met_data_typical[ds_key] = watershed_workflow.datasets.Dataset(ds_val.profile, new_times, smooth_dat)

attrs = watershed_workflow.daymet.getAttributes(bounds, new_times[0], new_times[-1])
attrs['name']=f"{ntypical_years}-yrs typical Daymet forcing generated using data from {start_date} to {end_date}"

watershed_workflow.io.write_dataset_to_hdf5(daymet_typical_filename, met_data_typical.collections[0], 
                                            attributes=attrs, time0=origin_date)
# Out:
# 2024-09-21 22:20:50,533 - root - INFO: Writing HDF5 file: ../../data/examples/CoalCreek/processed/coalcreek_daymet_typical.h5

# %%
# after smoothing, the forcing can look quite different!
ivar = 'air temperature [K]'
islice = 100
# daymet_crs = watershed_workflow.crs.daymet_crs()
profile = met_data_ats.collections[0].profile

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_workflow.plot.raster(profile, met_data_ats.collections[0].data[ivar][islice,:,:], ax1)
watershed_workflow.plot.hucs(watershed, crs, ax=ax1, color='r')

watershed_workflow.plot.raster(profile, met_data_typical.collections[0].data[ivar][islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Typical Daymet")
# Out:
# 2024-09-21 22:21:05,214 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364619, 4310206.812630757)
# 2024-09-21 22:21:05,217 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364619, 4310206.812630757)
# Text(0.5, 1.0, 'Typical Daymet')

# %% [markdown]
# Get mean precipitation for spinup

# %%
# # calculate the basin-averaged, annual-averaged precip rate
# precip_total = met_data_typical.collections[0].data['precipitation rain [m s^-1]'] + met_data_typical.collections[0].data['precipitation snow [m SWE s^-1]']
# mean_precip = precip_total.mean()
# config['mean_precip [m s^-1]'] = float(mean_precip)
# logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')


# calculate the basin-averaged, annual-averaged precip rate
precip_total = met_data_typical.collections[0].data['precipitation rain [m s^-1]'] + met_data_typical.collections[0].data['precipitation snow [m SWE s^-1]']
mean_precip = precip_total.mean()
# config['mean_precip [m s^-1]'] = float(mean_precip)
logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')
# Out:
# 2024-09-21 22:21:05,307 - root - INFO: Mean annual precip rate [m s^-1] = 2.2105914801440372e-08

# %%
# with open(config_fname, 'w') as file:
#     yaml.dump(config, file)
