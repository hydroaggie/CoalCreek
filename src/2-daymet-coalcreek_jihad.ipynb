# %% [markdown]
# # Download Daymet

# %% [markdown]
# Daymet provides gridded meteorological data for North American at 1km spatial resolution with daily timestep from 1980 ~ present. [website](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1328) and [user guide](https://daac.ornl.gov/DAYMET/guides/Daymet_V3_CFMosaics.html)
#
# Available variables:
#
# | Variable | Description (units) |
# | ---- | ---- |
# | tmax | Daily maximum 2-meter air temperature (°C) |
# | tmin | Daily minimum 2-meter air temperature (°C) |
# | prcp | Daily total precipitation (mm/day) |
# | srad | Incident shortwave radiation flux density (W/m2) |
# | vp   | Water vapor pressure (Pa) |
# | swe  | Snow water equivalent (kg/m2) |
# | dayl | Duration of the daylight period (seconds) |
#
# Notes:
#  - The Daymet calendar is based on a standard calendar year. <span style="color:blue;"> All Daymet years, including leap years, have 365 days. Keep this in mind during post-processing of model results!</span>  For leap years, the Daymet database includes leap day (February 29) and values for December 31 are discarded from leap years to maintain a 365-day year.
#
#  - DayMet's incident shortwave radiation is the "daylit" radiation.  To get the daily average radiation, one must multiply by daylit fraction, given by dayl / 86400.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
import logging,yaml
import numpy as np
import rasterio
import fiona
import os
import datetime 

import watershed_workflow
import watershed_workflow.ui
import watershed_workflow.sources.manager_daymet
import watershed_workflow.daymet
import watershed_workflow.io

watershed_workflow.ui.setup_logging(1,None)

# %%
watershed_shapefile = '../../data/examples/CoalCreek/sources/shapefile/CoalCreek.shp'
# config_fname = '../../data/examples/CoalCreek/processed/config.yaml'

# %%
# Load the dictionary from the file
with open(config_fname, 'r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load the dictionary from the file
# ----> 2 with open(config_fname, 'r') as file:
#       3     config = yaml.load(file, Loader=yaml.FullLoader)
#
# NameError: name 'config_fname' is not defined

# %%
# dates are in YYYY-MM-DD
# start and end of simulation -- one year of simulation that is in both the MODIS and DayMet dataset ranges
# start_date = config['start_date']
# end_date = config['end_date']
# origin_date = config['origin_date']

start_date = "2014-10-1"
end_date = "2022-10-1"
# origin_date = config['origin_date']
origin_date = "1980-1-1"

# %% [markdown]
# ## import watershed

# %%
crs, watershed = watershed_workflow.get_split_form_shapes(watershed_shapefile)
logging.info(f'crs: {crs}')

bounds = watershed.exterior().bounds
print(bounds)
print(bounds[2] - bounds[0], bounds[3] - bounds[1])
# Out:
# 2024-03-08 15:21:51,350 - root - INFO:
# 2024-03-08 15:21:51,350 - root - INFO: Loading shapes
# 2024-03-08 15:21:51,350 - root - INFO: ------------------------------
# 2024-03-08 15:21:51,350 - root - INFO: Loading file: '../../data/examples/CoalCreek/sources/shapefile/CoalCreek.shp'
# 2024-03-08 15:21:51,360 - root - INFO: ... found 1 shapes
# 2024-03-08 15:21:51,360 - root - INFO: Converting to shapely
# 2024-03-08 15:21:51,360 - root - INFO:  ... done
# 2024-03-08 15:21:51,360 - root - INFO: Removing holes on 1 polygons
# 2024-03-08 15:21:51,360 - root - INFO:   -- removed interior
# 2024-03-08 15:21:51,360 - root - INFO:   -- union
# 2024-03-08 15:21:51,360 - root - INFO: Parsing 1 components for holes
# 2024-03-08 15:21:51,377 - root - INFO:   -- complete
# 2024-03-08 15:21:51,377 - root - INFO: crs: EPSG:26913
# (317251.2640131897, 4299711.408984916, 328473.7039815487, 4307062.45088187)
# 11222.439968359016 7351.041896954179

# %%
watershed.exterior()

# %% [markdown]
# ## Download

# %% [markdown]
# returned raw data has `dim(nband, ncol, nrow)`

# %%
# setting vars = None to download all available variables
source = watershed_workflow.sources.manager_daymet.FileManagerDaymet()
data = source.get_data(bounds, crs, start = start_date, end = end_date, buffer=0.02)
# Out:
# 2024-03-08 15:21:57,102 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,102 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,102 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,102 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,102 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,118 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,118 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,118 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,118 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,118 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,118 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,118 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,118 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,118 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,134 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,134 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,134 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,134 - root - INFO:   Using existing: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmin_2022_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:21:57,134 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:21:57,134 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2014.nc
# 2024-03-08 15:21:57,134 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:23:11,461 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:23:11,461 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2015.nc
# 2024-03-08 15:23:11,461 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:28:46,209 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:28:46,213 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2016.nc
# 2024-03-08 15:28:46,213 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:29:50,083 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:29:50,086 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2017.nc
# 2024-03-08 15:29:50,088 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:30:48,684 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:30:48,687 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2018.nc
# 2024-03-08 15:30:48,688 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:31:42,955 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:31:42,958 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2019.nc
# 2024-03-08 15:31:42,959 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:33:43,056 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:33:43,056 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2020.nc
# 2024-03-08 15:33:43,071 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:35:23,973 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:35:23,982 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2021.nc
# 2024-03-08 15:35:23,987 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:35:52,490 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:35:52,490 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_tmax_2022.nc
# 2024-03-08 15:35:52,490 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_tmax_2022_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:35:59,347 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:35:59,347 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2014.nc
# 2024-03-08 15:35:59,347 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:37:51,897 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:37:51,897 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2015.nc
# 2024-03-08 15:37:51,897 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:39:49,566 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:39:49,571 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2016.nc
# 2024-03-08 15:39:49,571 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:41:41,035 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:41:41,051 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2017.nc
# 2024-03-08 15:41:41,051 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:43:19,441 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:43:19,445 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2018.nc
# 2024-03-08 15:43:19,445 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:44:27,760 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:44:27,760 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2019.nc
# 2024-03-08 15:44:27,760 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:45:26,357 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:45:26,357 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2020.nc
# 2024-03-08 15:45:26,357 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:46:08,793 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:46:08,793 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2021.nc
# 2024-03-08 15:46:08,793 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:46:50,687 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:46:50,687 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_prcp_2022.nc
# 2024-03-08 15:46:50,687 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_prcp_2022_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:48:04,040 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:48:04,043 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2014.nc
# 2024-03-08 15:48:04,044 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:50:26,973 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:50:26,973 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2015.nc
# 2024-03-08 15:50:26,973 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:52:38,908 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:52:38,909 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2016.nc
# 2024-03-08 15:52:38,909 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:55:29,469 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:55:29,469 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2017.nc
# 2024-03-08 15:55:29,469 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:58:15,771 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:58:15,773 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2018.nc
# 2024-03-08 15:58:15,774 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 15:59:46,791 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 15:59:46,796 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2019.nc
# 2024-03-08 15:59:46,799 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:01:38,823 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:01:38,829 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2020.nc
# 2024-03-08 16:01:38,829 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:02:28,485 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:02:28,485 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2021.nc
# 2024-03-08 16:02:28,485 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:03:02,710 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:03:02,725 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_srad_2022.nc
# 2024-03-08 16:03:02,725 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_srad_2022_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:03:27,474 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:03:27,480 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2014.nc
# 2024-03-08 16:03:27,482 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:05:32,620 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:05:32,623 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2015.nc
# 2024-03-08 16:05:32,625 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:07:21,929 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:07:21,932 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2016.nc
# 2024-03-08 16:07:21,932 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:10:13,172 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:10:13,175 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2017.nc
# 2024-03-08 16:10:13,176 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:12:18,925 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:12:18,925 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2018.nc
# 2024-03-08 16:12:18,925 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:14:38,797 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:14:38,802 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2019.nc
# 2024-03-08 16:14:38,802 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:16:34,312 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:16:34,316 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2020.nc
# 2024-03-08 16:16:34,317 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:17:23,470 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:17:23,470 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2021.nc
# 2024-03-08 16:17:23,470 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:18:00,336 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:18:00,339 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_vp_2022.nc
# 2024-03-08 16:18:00,339 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_vp_2022_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:18:38,235 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:18:38,235 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2014.nc
# 2024-03-08 16:18:38,235 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2014_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:19:25,719 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:19:25,719 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2015.nc
# 2024-03-08 16:19:25,719 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2015_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:20:10,066 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:20:10,081 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2016.nc
# 2024-03-08 16:20:10,081 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2016_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:20:54,190 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:20:54,190 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2017.nc
# 2024-03-08 16:20:54,190 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2017_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:21:30,847 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:21:30,847 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2018.nc
# 2024-03-08 16:21:30,847 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2018_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:22:16,485 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:22:16,485 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2019.nc
# 2024-03-08 16:22:16,485 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2019_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:23:04,087 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:23:04,087 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2020.nc
# 2024-03-08 16:23:04,087 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2020_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:23:51,450 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:23:51,450 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2021.nc
# 2024-03-08 16:23:51,450 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2021_38.9157x-107.1272_38.8072x-106.9560.nc
# 2024-03-08 16:24:42,849 - root - INFO: Collecting DayMet file to tile bounds: [-107.1272, 38.8072, -106.956, 38.9157]
# 2024-03-08 16:24:42,854 - root - INFO:   Downloading: http://thredds.daac.ornl.gov/thredds/ncss/grid/ornldaac/2129/daymet_v4_daily_na_dayl_2022.nc
# 2024-03-08 16:24:42,854 - root - INFO:       to file: C:\Users\jihad\ats-workflow\src\chapters\data\meteorology\daymet\daymet_dayl_2022_38.9157x-107.1272_38.8072x-106.9560.nc

# %% [markdown]
# ## Reproject Daymet CRS
#
# Reproject daymet CRS to the same as the watershed. This is necessary if watershed meshes are using watershed CRS.

# %%
data_new = watershed_workflow.warp.state(data, dst_crs=crs)

# %% [markdown]
# ## plot Daymet

# %%
ivar = 'tmax'
islice = 100
daymet_crs = watershed_workflow.crs.daymet_crs()

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(daymet_crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_ext_daymet = watershed_workflow.warp.shply(watershed.exterior(),
                                                     crs, daymet_crs)
watershed_workflow.plot.raster(data[ivar].profile, data[ivar].data[islice,:,:], ax1)
watershed_workflow.plot.shply(watershed_ext_daymet, daymet_crs, ax=ax1, color='r')

watershed_workflow.plot.raster(data_new[ivar].profile, data_new[ivar].data[islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Reprojected Daymet")
# Out:
# C:\Users\jihad\miniforge-pypy3\envs\ENV_ATS\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# C:\Users\jihad\miniforge-pypy3\envs\ENV_ATS\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 2024-03-08 16:37:26,399 - root - INFO: BOUNDS: (-591250.0, -367000.0, -576250.0, -355000.0)
# 2024-03-08 16:37:26,886 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364615, 4310206.812630757)
# C:\Users\jihad\miniforge-pypy3\envs\ENV_ATS\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# Text(0.5, 1.0, 'Reprojected Daymet')

# %% [markdown]
# # save daymet

# %% [markdown]
# ## Write data to HDF5

# %% [markdown]
# This will write daymet in a format that ATS can read. E.g., this will calculate mean air temperature, convert units, partition precipitation into rain and snow based on mean temp, and so on.
#
# - dout has dims of `(ntime, nrow, ncol)` or `(ntime, ny, nx)`

# %%
assert(len(data_new.collections) == 1)
met_data = data_new.collections[0]

# %%
# met_data_ats = watershed_workflow.daymet.daymet_to_daily_averages(met_data)


# config['daymet_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_raw.h5')
# attrs = watershed_workflow.daymet.getAttributes(bounds, start_date, end_date)
# attrs['name']="Daymet forcing reformatted for ats modeling"

# watershed_workflow.io.write_dataset_to_hdf5(
#     filename = config['daymet_filename'],
#     dataset= met_data_ats.collections[0],
#     attributes= attrs,
#     time0 = origin_date
# )


met_data_ats = watershed_workflow.daymet.daymet_to_daily_averages(met_data)
daymet_filename = os.path.join('..', '..', 'data', 'examples', 'CoalCreek', 'processed', 'watershed_daymet_raw.h5')

# Get attributes for the dataset
attrs = watershed_workflow.daymet.getAttributes(bounds, start_date, end_date)
attrs['name']="Daymet forcing reformatted for ats modeling"

# Write the processed Daymet data to an HDF5 file
watershed_workflow.io.write_dataset_to_hdf5(
    filename=daymet_filename,
    dataset= met_data_ats.collections[0],
    attributes= attrs,
    time0 = origin_date
)
# Out:
# 2024-03-08 19:31:54,415 - root - INFO: Converting to ATS met input
# 2024-03-08 19:31:54,622 - root - INFO: Writing HDF5 file: ..\..\data\examples\CoalCreek\processed\watershed_daymet_raw.h5

# %% [markdown]
# ## Write typical Daymet
#
# This will average days, smooths the forcing and generate a "typical year" data, then looped 10 years. The dataset will be used during cyclic spinup.

# %%
# config['daymet_typical_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')

# met_data_typical = watershed_workflow.datasets.State()
# ntypical_years = 10
# # here we make up some new times. 
# # It does not really matter what timeframe you choose as long as the nunmber of days are consistent.
# new_times = np.array([datetime.date(1980,10,1) + datetime.timedelta(days=i) for i in range(365*ntypical_years)])

# for (ds_key, ds_val) in met_data_ats.items():
#     # average and smooth forcing data. Hint: make filter=False if no smoothing is needed.
#     smooth_dat = watershed_workflow.utils.compute_average_year(ds_val.data, output_nyears=ntypical_years, filter=True)
#     met_data_typical[ds_key] = watershed_workflow.datasets.Dataset(ds_val.profile, new_times, smooth_dat)

# attrs = watershed_workflow.daymet.getAttributes(bounds, new_times[0], new_times[-1])
# attrs['name']=f"{ntypical_years}-yrs typical Daymet forcing generated using data from {start_date} to {end_date}"

# watershed_workflow.io.write_dataset_to_hdf5(config['daymet_typical_filename'], met_data_typical.collections[0], 
#                                             attributes=attrs, time0=origin_date)


daymet_typical_filename = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')
# config['daymet_typical_filename'] = os.path.join('..', '..', 'data', 'examples','CoalCreek', 'processed','watershed_daymet_typical.h5')

met_data_typical = watershed_workflow.datasets.State()
ntypical_years = 10
# here we make up some new times. 
# It does not really matter what timeframe you choose as long as the nunmber of days are consistent.
new_times = np.array([datetime.date(1980,10,1) + datetime.timedelta(days=i) for i in range(365*ntypical_years)])

for (ds_key, ds_val) in met_data_ats.items():
    # average and smooth forcing data. Hint: make filter=False if no smoothing is needed.
    smooth_dat = watershed_workflow.utils.compute_average_year(ds_val.data, output_nyears=ntypical_years, filter=True)
    met_data_typical[ds_key] = watershed_workflow.datasets.Dataset(ds_val.profile, new_times, smooth_dat)

attrs = watershed_workflow.daymet.getAttributes(bounds, new_times[0], new_times[-1])
attrs['name']=f"{ntypical_years}-yrs typical Daymet forcing generated using data from {start_date} to {end_date}"

watershed_workflow.io.write_dataset_to_hdf5(daymet_typical_filename, met_data_typical.collections[0], 
                                            attributes=attrs, time0=origin_date)
# Out:
# 2024-03-08 19:38:54,906 - root - INFO: Writing HDF5 file: ..\..\data\examples\CoalCreek\processed\watershed_daymet_typical.h5

# %%
# after smoothing, the forcing can look quite different!
ivar = 'air temperature [K]'
islice = 100
# daymet_crs = watershed_workflow.crs.daymet_crs()
profile = met_data_ats.collections[0].profile

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_workflow.plot.raster(profile, met_data_ats.collections[0].data[ivar][islice,:,:], ax1)
watershed_workflow.plot.hucs(watershed, crs, ax=ax1, color='r')

watershed_workflow.plot.raster(profile, met_data_typical.collections[0].data[ivar][islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Typical Daymet")
# Out:
# C:\Users\jihad\miniforge-pypy3\envs\ENV_ATS\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 2024-03-08 19:39:22,476 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364615, 4310206.812630757)
# 2024-03-08 19:39:22,539 - root - INFO: BOUNDS: (314692.7009557779, 4296566.393670194, 331256.0668364615, 4310206.812630757)
# C:\Users\jihad\miniforge-pypy3\envs\ENV_ATS\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# Text(0.5, 1.0, 'Typical Daymet')

# %% [markdown]
# Get mean precipitation for spinup

# %%
# # calculate the basin-averaged, annual-averaged precip rate
# precip_total = met_data_typical.collections[0].data['precipitation rain [m s^-1]'] + met_data_typical.collections[0].data['precipitation snow [m SWE s^-1]']
# mean_precip = precip_total.mean()
# config['mean_precip [m s^-1]'] = float(mean_precip)
# logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')


# calculate the basin-averaged, annual-averaged precip rate
precip_total = met_data_typical.collections[0].data['precipitation rain [m s^-1]'] + met_data_typical.collections[0].data['precipitation snow [m SWE s^-1]']
mean_precip = precip_total.mean()
# config['mean_precip [m s^-1]'] = float(mean_precip)
logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')
# Out:
# 2024-03-08 19:40:57,201 - root - INFO: Mean annual precip rate [m s^-1] = 2.220359024453574e-08

# %%
# with open(config_fname, 'w') as file:
#     yaml.dump(config, file)
